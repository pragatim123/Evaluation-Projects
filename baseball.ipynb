# %% [markdown]
# #                                   BASEBALL PROJECT

# %% [markdown]
# # Importing neccessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importing dataset

# %%
df=pd.read_csv("baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# # Problem indentification

# %% [markdown]
# Problem Goal:Inorder to develop an algorithm that predicts the number of "wins" for a given team in the 2015 season based on several different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
# As all values are in numeric form and we need to predict continous value for the number of wins.So this problem is a regression problem

# %%
df.head() # first 5 rows of dataset
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail() # last 5 rows of dataset
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.sample(5) # taking 5 samples from dataset
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 11  86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 1   83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 6   87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7   81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 10  88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
#
#     SHO  SV    E
# 11   13  39   85
# 1    12  45   86
# 6     4  48   93
# 7    10  43   77
# 10    9  45  119

# %% [markdown]
# The dataset contains only numeric values.
#
# Input features: R=Runs, AB=At Bats, H=Hits, 2B=Doubles, 3B=triples, HR=HomeRuns, BB=Base on Balls(/walk), SO=Strikeouts, SB=Stolen Bases, RA=Run Average, ER=Earned Runs, ERA=Earned Run Average, CG=Complete Games, SHO=Shutouts, SV=Save, E=Errors.
#
# Output feature: W=Wins(Number of predicted wins)

# %%
df.shape #shape of data
# Out:
# (30, 17)

# %% [markdown]
# The dataset contains 30 rows and 17 columns.

# %%
df.dtypes # chking datatypes of all columns
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# The dataset contains 16 integer-type and one float-type.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#displaying all the input features plus one target value.
df.keys()
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# # EDA

# %%
#chking null values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There are no null values in our dataset so we can proceed further

# %%
# lets have some statistics over our dataset
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# 1.We can see that mean is greater than median in "AB","H" ,"HR" columns.
#
# 2.There is a large difference between 75th percentile and maximum value in the columns "R","SO","ER", so there might be a presence of large number of outliers.

# %%
# lets chk the unique values in target column W
df["W"].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79])

# %%
df["W"].value_counts()
# Out:
# 68     3
# 83     2
# 74     2
# 76     2
# 81     2
# 64     1
# 93     1
# 92     1
# 90     1
# 88     1
# 87     1
# 86     1
# 85     1
# 84     1
# 80     1
# 97     1
# 100    1
# 78     1
# 63     1
# 79     1
# 71     1
# 67     1
# 98     1
# 95     1
# Name: W, dtype: int64

# %% [markdown]
# There are many unique values in our target/dependent column which means the target data is imbalanced.

# %% [markdown]
# # Univariate analysis - count plot and hist plot for every column

# %%
#importing libraries
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
sns.histplot(df["W"])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Count'>

# %%
sns.countplot(df["W"])
# Out:
# <AxesSubplot:xlabel='W', ylabel='count'>

# %% [markdown]
# The data distribution is not normal about the mean.

# %%
sns.countplot(df["R"])
# Out:
# <AxesSubplot:xlabel='R', ylabel='count'>

# %%
sns.histplot(df["R"])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Count'>

# %% [markdown]
# Here the data distribution is not normal.

# %%
sns.histplot(df["AB"])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Count'>

# %%
sns.countplot(df["AB"])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='count'>

# %% [markdown]
# The data distribution is not normal about the mean.

# %%
sns.countplot(df["H"])
# Out:
# <AxesSubplot:xlabel='H', ylabel='count'>

# %%
sns.histplot(df["H"])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Count'>

# %% [markdown]
# Data distribution is not normal about the mean.

# %%
sns.histplot(df["2B"])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Count'>

# %%
sns.countplot(df["2B"])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='count'>

# %% [markdown]
# The distribution of data is not normal in all columns.

# %%
sns.countplot(df['3B'])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='count'>

# %%
sns.histplot(df['3B'])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Count'>

# %% [markdown]
# The data distribution is not normal here.

# %%
sns.histplot(df['HR'])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Count'>

# %%
sns.countplot(df['HR'])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='count'>

# %% [markdown]
# The data distribution is not normal.

# %%
sns.histplot(df['BB'])
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Count'>

# %%
sns.countplot(df['BB'])
# Out:
# <AxesSubplot:xlabel='BB', ylabel='count'>

# %% [markdown]
# The data distribution is not normal.

# %%
sns.countplot(df['SO'])
# Out:
# <AxesSubplot:xlabel='SO', ylabel='count'>

# %%
sns.histplot(df['SO'])
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Count'>

# %% [markdown]
# The distribution of data is not normal

# %%
sns.histplot(df['SB'])
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Count'>

# %%
sns.countplot(df['SB'])
# Out:
# <AxesSubplot:xlabel='SB', ylabel='count'>

# %% [markdown]
# The data distribution is not normal.

# %%
sns.countplot(df['RA'])
# Out:
# <AxesSubplot:xlabel='RA', ylabel='count'>

# %%
sns.histplot(df['RA'])
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Count'>

# %% [markdown]
# Data distribution is not normal.

# %%
sns.histplot(df['ER'])
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Count'>

# %%
sns.countplot(df['ER'])
# Out:
# <AxesSubplot:xlabel='ER', ylabel='count'>

# %% [markdown]
# Data distribution is not normal here.

# %%
sns.countplot(df['ERA'])
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='count'>

# %%
sns.histplot(df['ERA'])
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Count'>

# %% [markdown]
# Data distribution is normal.

# %%
sns.histplot(df['CG'])
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Count'>

# %%
sns.countplot(df['CG'])
# Out:
# <AxesSubplot:xlabel='CG', ylabel='count'>

# %% [markdown]
# Distribution of data is not normal about the mean.

# %%
sns.countplot(df['SHO'])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='count'>

# %%
sns.histplot(df['SHO'])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Count'>

# %% [markdown]
# Here the distribution of data is normal but there is a slight right skewed curve.

# %%
sns.histplot(df['SV'])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Count'>

# %%
sns.countplot(df['SV'])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='count'>

# %% [markdown]
# Data distribution is not normal.

# %%
sns.countplot(df['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='count'>

# %%
sns.histplot(df['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Count'>

# %% [markdown]
# The distribution of data is not normal.
#
# Observations:
#
# 1.We can see that the data in the columns "ERA" and "SHO" are normally distributed and remaining are having a variance of data over the mean.
#
# 2.This indicates that the standard deviation is not in the range of +/-1 in those columns which are not normal about the mean.

# %% [markdown]
# # heatmap for null values

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# The above graph clearly says that there is a absence of null values.

# %% [markdown]
# # Bi-variate analysis

# %% [markdown]
# Let us graphically analyze all the input features with the target feature.

# %%
df.plot(kind="scatter",x="R",y="W")
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %% [markdown]
# We can see that there is positive impact of Runs on target "W" as Runs scored by a player increases the winning chances increases. Also their is an outlier lying the range of (850,900).

# %%
df.plot(kind="scatter",x='AB',y="W") #showing how data is scatter betweenAB and W
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %%
df.plot(kind="scatter",x='H',y="W") #scatter plot H and W
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
df.plot(kind="scatter",x="2B",y="W")
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %% [markdown]
# Here the "2B" is positively impacting our target variable 'W' which means increase in Doubles can increase the chances of winning.

# %%
df.plot(kind="scatter",x="3B",y="W")
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %%
df.plot(kind="scatter",x='HR',y='W')
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %%
df.plot(kind="scatter",x="BB",y="W")
# Out:
# <AxesSubplot:xlabel='BB', ylabel='W'>

# %% [markdown]
# A linear curve indicating the positive relation with the target variable.

# %%
df.plot(kind="scatter",x="SO",y='W')
# Out:
# <AxesSubplot:xlabel='SO', ylabel='W'>

# %%
df.plot(kind='scatter',x='SB',y="W") #showing scatter plot is distrubuted values
# Out:
# <AxesSubplot:xlabel='SB', ylabel='W'>

# %%
df.plot(kind="scatter",x='RA',y='W') #plotting showing reverse linear negative impact
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %% [markdown]
# The above graph clearly shows that there is a negative impact of 'RA' on target "W" which implies there is a gradual declining of curve as the "RA" increases.

# %%
df.plot(kind="scatter",x="ER",y="W")
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %% [markdown]
# Here also we can see that there is a negative relation between "ER" and "W".

# %%
df.plot(kind="scatter",x="ERA",y="W")
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %% [markdown]
# As "ERA" increases out target variable "W" is decreasing which is a negative correlation.

# %%
df.plot(kind='scatter',x="CG",y='W')
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %% [markdown]
# There is an outlier lying above 10.

# %%
df.plot(kind="scatter",x="SHO",y="W")
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='W'>

# %%
df.plot(kind="scatter",x='SV',y="W")
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %% [markdown]
# Here we can see there is some positive correlation between input feature "SV" and a output feature "W".

# %%
df.plot(kind="scatter",x="E",y="W")
# Out:
# <AxesSubplot:xlabel='E', ylabel='W'>

# %% [markdown]
# Observations:
#
# 1.The input features "RA","ER" and "ERA" are negatively impacting the target variable "W".
#
# 2.The input features "R","BB","SV","SHO","SO" are positively imapcting the target variable.
#
# 3.Remaining features are contributing some percent for the target variable.
#
# Let us proceed to check the correlation of the data.

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %% [markdown]
# # heatmap of correlation amonng input and target data

# %%
plt.figure(figsize=(8,9))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observations:
#
# 1.The dark shades indicates higly negative correlation.
#
# 2.The lighter shades indicates higly positive correlation.
#
# 3.So our target variable is having a highly negative correlation with the input features "RA","ER","ERA" as observed in the scatter graphs also.

# %%
plt.figure(figsize=(15,12))
sns.heatmap(df.corr(),cmap="Blues",annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Chking for outliers

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.plot(kind='box',subplots=True,layout=(4,5))
# Out:
# W          AxesSubplot(0.125,0.71587;0.133621x0.16413)
# R       AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# AB       AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# H       AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# 2B      AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# 3B        AxesSubplot(0.125,0.518913;0.133621x0.16413)
# HR     AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# BB      AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# SO     AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# SB     AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# RA        AxesSubplot(0.125,0.321957;0.133621x0.16413)
# ER     AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# ERA     AxesSubplot(0.44569,0.321957;0.133621x0.16413)
# CG     AxesSubplot(0.606034,0.321957;0.133621x0.16413)
# SHO    AxesSubplot(0.766379,0.321957;0.133621x0.16413)
# SV           AxesSubplot(0.125,0.125;0.133621x0.16413)
# E         AxesSubplot(0.285345,0.125;0.133621x0.16413)
# dtype: object

# %% [markdown]
# By observing all the above graphs we can see that there is a lot of outliers in the 'E' graph.

# %% [markdown]
# # Normal Distribution curve

# %%
#distplot showing plotting between all inputs data
for i in df.columns:
    plt.figure()
    sns.distplot(df[i])

# %% [markdown]
# showing that how input data are normally distrubuted

# %% [markdown]
# # pairplot

# %%
sns.pairplot(df)

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# # Removing outliers

# %%
# import libraries
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
# array([[1.36540860e+00, 6.19077968e-01, 8.47731264e-01, 1.66368512e+00,
#         1.42017307e+00, 1.04119304e+00, 7.87298598e-01, 1.53490242e+00,
#         2.69762957e+00, 9.13883291e-01, 6.66233927e-01, 5.05110079e-01,
#         5.06955186e-01, 5.39806195e-01, 8.14628593e-01, 1.67160651e+00,
#         4.61469635e-01],
#        [1.97838300e-01, 1.34431656e-01, 7.11093535e-01, 9.70680764e-01,
#         1.27403389e-01, 1.23580856e+00, 2.43966683e-01, 5.36591904e-01,
#         1.54878442e-01, 6.01825582e-01, 1.65970766e-01, 2.48929848e-01,
#         2.54597523e-01, 5.39806195e-01, 1.72800005e-01, 2.49879323e-01,
#         6.07196888e-01],
#        [3.24325082e-03, 3.32905860e-01, 1.11523330e+00, 1.51891367e-01,
#         1.58879521e+00, 2.23807850e-01, 7.23377196e-01, 1.13914361e+00,
#         8.93981893e-01, 1.11449182e-01, 6.80339091e-01, 7.51623132e-01,
#         6.41346840e-01, 2.77264091e+00, 3.20914294e-01, 6.54856158e-01,
#         1.11724227e+00],
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5]), array([1]))

# %%
df_new=df[(z<3).all(axis=1)]
df_new.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
print("df shape:",df.shape)
print("df_new shape:",df_new.shape)
# Out:
# df shape: (30, 17)
# df_new shape: (29, 17)

# %% [markdown]
# # Loss Percent

# %%
loss_percent=(30-29)/30*100
loss_percent #loss percentage
# Out:
# 3.3333333333333335

# %% [markdown]
# # Standard Scalar

# %%
from sklearn.preprocessing import StandardScaler #importing library

ss = StandardScaler()
x_scalar = ss.fit_transform(x)

# %% [markdown]
# # Chking for Multicolinearity

# %%
#import libraries
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["vif"] = [variance_inflation_factor(x_scalar, i) for i in range(x_scalar.shape[1])]
vif["Features"] = x.columns

#lets check the values
vif
# Out:
#          vif Features
# 0   6.787762        R
# 1   4.981743       AB
# 2   8.569581        H
# 3   3.416116       2B
# 4   3.239565       3B
# 5   6.590925       HR
# 6   3.081560       BB
# 7   2.106522       SO
# 8   1.842528       SB
# 9   4.931066      ERA
# 10  2.649063       CG
# 11  3.231029      SHO
# 12  3.075865       SV
# 13  2.039641        E

# %% [markdown]
# as we have saw in the table vif value is greater than 5 for many columns, so drop maximum value column to avoid multiclinearity issue.

# %%
df_new=df_new.drop(['ER'], axis=1) #drop ER column as vIF is very large

# %%
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ERA  CG  SHO  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  3.73   2    8
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  4.07   2   12
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  3.67  11   10
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  3.98   7    9
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  4.64   7   12
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  4.03   3    4
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  4.05   0   10
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  3.74   1   12
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  4.31   3   10
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  4.24   5    9
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  3.57   5   13
# ...

# %%
x = df_new.drop(columns = 'W', axis=1)
y = df_new['W']

# %%
ss = StandardScaler()
x_scalar = ss.fit_transform(x)

# %%
# chking VIF
#import libraries
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["vif"] = [variance_inflation_factor(x_scalar, i) for i in range(x_scalar.shape[1])]
vif["Features"] = x.columns

#lets check the values
vif
# Out:
#            vif Features
# 0     6.789990        R
# 1     7.689961       AB
# 2     9.703669        H
# 3     3.423326       2B
# 4     3.268301       3B
# 5     7.683683       HR
# 6     3.430050       BB
# 7     2.713114       SO
# 8     1.907595       SB
# 9   144.425392       RA
# 10  139.967064      ERA
# 11    2.649316       CG
# 12    3.498198      SHO
# 13    3.174949       SV
# 14    2.092189        E

# %%
df_new=df_new.drop(['RA'], axis=1) #drop RA column

# %%
x = df_new.drop(columns = 'W', axis=1)
y = df_new['W']

# %%
ss = StandardScaler()
x_scalar = ss.fit_transform(x)

# %%
#chking Vif again
vif = pd.DataFrame()
vif["vif"] = [variance_inflation_factor(x_scalar, i) for i in range(x_scalar.shape[1])]
vif["Features"] = x.columns

#lets check the values
vif
# Out:
#          vif Features
# 0   6.787762        R
# 1   4.981743       AB
# 2   8.569581        H
# 3   3.416116       2B
# 4   3.239565       3B
# 5   6.590925       HR
# 6   3.081560       BB
# 7   2.106522       SO
# 8   1.842528       SB
# 9   4.931066      ERA
# 10  2.649063       CG
# 11  3.231029      SHO
# 12  3.075865       SV
# 13  2.039641        E

# %% [markdown]
# as we have saw in the table vif value is not greater than 5 for columns, so we can proceed further now.

# %%
# importing libraries for training and testing and importing metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


#from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score

# %% [markdown]
# # Finding the best random state

# %%
from sklearn.tree import DecisionTreeRegressor
maxAccu = 0
maxRS = 0
for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=.20, random_state=i)
    mod= DecisionTreeRegressor()
    mod.fit(x_train, y_train)
    pred = mod.predict(x_test)
    acc=r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu, "on Random_state ", maxRS)
# Out:
# Best accuracy is  0.852504638218924 on Random_state  94

# %%
 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=94)

# %% [markdown]
# # boosting of model by adaboost

# %%
from sklearn.ensemble import AdaBoostRegressor
ada = AdaBoostRegressor()

# %%
ada.fit(x_train, y_train)
y_pred = ada.predict(x_train)

# %%
from sklearn import metrics
print('r square score', metrics.r2_score(y_train, y_pred))
# Out:
# r square score 0.9869580823788836

# %%
cv_score= cross_val_score(ada, x, y, cv=5, scoring='r2')

cv_mean=cv_score.mean()
cv_mean
# Out:
# -0.8693436478473358

# %% [markdown]
# The r2 score is 99% and cross validation is -0.86

# %% [markdown]
# # Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

Lr=LinearRegression()
Lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred_test=Lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.4792805468496495

# %%
lm.score(x_train,y_train)*100
# Out:
# 59.505759874095396

# %%
#cross validation of linear regression

from sklearn.model_selection import cross_val_score
cv_score= cross_val_score(Lr, x, y, cv=5, scoring='r2')

cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.2956162841694372

# %% [markdown]
# The r2 score for linear regression model is : 59%
# Cross validation score for linear regression is : 29.5

# %% [markdown]
# # Regularization

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
ls = Lasso()
parameters = {'alpha' :[.0001, .001, .01, .1, 1, 10], 'random_state':list(range(0,10))}
ls = Lasso()
clf = GridSearchCV(ls, parameters)
clf.fit(x_train, y_train)

print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls = Lasso(alpha = 1, random_state=0)
ls.fit(x_train, y_train)
ls.score(x_train, y_train)
pred_ls = ls.predict(x_test)

laso = r2_score(y_test, pred_ls)
laso
# Out:
# 0.6013355718803648

# %% [markdown]
# The r2 score is 60%

# %% [markdown]
# # DecisionTreeRegressor():

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
pred_dt = dt.predict(x_test)
print(r2_score(y_test,pred_dt))
# Out:
# -0.010060362173038184

# %%
cv_score= cross_val_score(dt, x, y, cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# -2.2138892101994787

# %% [markdown]
# The r2 score is -0.01% and cross validation score is -2.21

# %% [markdown]
# # Support Vector Regressor:

# %%
from sklearn.svm import SVR

# %%
svr = SVR()
svr.fit(x_train, y_train)
# Out:
# SVR()

# %%
pred_svr = svr.predict(x_test)
print(r2_score(y_test,pred_svr))
# Out:
# -0.09812571587027463

# %%
cv_score= cross_val_score(svr, x, y, cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# -0.4311714681013945

# %% [markdown]
# The r2 score is -0.098 and cross validation is -0.43

# %% [markdown]
# # GradientBoostRegressor:

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor()
gbr.fit(x_train, y_train)
gbr.fit(x_test, y_test)
# Out:
# GradientBoostingRegressor()

# %%
pred_test=gbr.predict(x_test)
print(r2_score(y_test,pred_test))
# Out:
# 0.9999999992619717

# %%
gbr.score(x_test, y_test)*100
# Out:
# 99.99999992619718

# %%
cv_score= cross_val_score(gbr, x, y, cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# -1.414316122272631

# %% [markdown]
# The r2 score of gradient boosting is 99% and cross validation is -1.302

# %% [markdown]
# # GaussianNB:

# %%
from sklearn.naive_bayes import GaussianNB
regressor = GaussianNB()
regressor.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
pred_test=regressor.predict(x_test)
print(r2_score(y_test,pred_test))
# Out:
# -1.9336016096579476

# %%
nb_accuracy = round(regressor.score(x_train,y_train)*100,2)
nb_accuracy
# Out:
# 100.0

# %%
scr = cross_val_score(regressor,x,y,cv=3,scoring='r2')
print("cross validation score of svr model:",scr.mean())
# Out:
# cross validation score of svr model: -1.1087165948019886

# %% [markdown]
# The r2 score of gaussian Nb is -1.17 and cross validation is -1.1087

# %% [markdown]
# # RandomForestRegressor:

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train,y_train)
y_pred = rf.predict(x_test)

# %%
pred_test=rf.predict(x_test)
print(r2_score(y_test,pred_test))
# Out:
# 0.550403118712274

# %%
scr = cross_val_score(rf,x,y,cv=3,scoring='r2')
print("cross validation score of svr model:",scr.mean()*100)
# Out:
# cross validation score of svr model: -19.285631301050223

# %%
The r2 score of random forest regressor is 55%
the cross validation score of random forest is -19

# %% [markdown]
# on comparing the cross validation score with accuracy linear regression model is having less difference so let us proceed to hypertuning.

# %% [markdown]
# # Hyperparameter tuning

# %%
#using 5 hyper parameters:
parameters = { "fit_intercept":[True,False], 
              "normalize":[False,True], 
              "copy_X":[True,False], 
              "n_jobs":[0.1,0.22,-1,-2], 
              "positive":[False,True]
              }

# %%
gcv=GridSearchCV(lm,parameters,cv=3)

# %%
gcv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'n_jobs': [0.1, 0.22, -1, -2],
#                          'normalize': [False, True],
#                          'positive': [False, True]})

# %%
# best parameters
gcv.best_params_
# Out:
# {'copy_X': True,
#  'fit_intercept': False,
#  'n_jobs': 0.1,
#  'normalize': False,
#  'positive': True}

# %% [markdown]
# # Final model

# %%
final_mod =LinearRegression(copy_X=True,fit_intercept=False, n_jobs= 0.1, normalize= False, positive= True)
final_mod.fit(x_train,y_train)
pred=final_mod.predict(x_test)
acc=r2_score(y_test,pred)
print(acc*100)
# Out:
# 85.39751630795915

# %% [markdown]
# That's great our model accuracy improves from 59.5% to 85%

# %% [markdown]
# # Saving final model

# %%
#saving the final model
import joblib
joblib.dump(Lr,"Finalbase.pkl")
# Out:
# ['Finalbase.pkl']

# %% [markdown]
# # Conclusion

# %%
preds = Lr.predict(x_test)
dataframe=pd.DataFrame({})
print("Predicted wins:",preds[:10])
print("Actual wins:",y_test[0:10].values)
# Out:
# Predicted wins: [85.68064052 93.15868115 74.66474737 65.51275441 80.54225791 62.79002312
#  70.31931764 81.35100752]
# Actual wins: [ 97 100  79  74  90  64  83  81]
